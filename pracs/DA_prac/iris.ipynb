# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data=pd.read_csv("iris.csv")

# %%
data.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
data.columns=['sepal length','sepal width','petal length','petal width','class']

# %%
data.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %%
data['class'].value_counts()
# Out:
# Iris-virginica     50
# Iris-versicolor    50
# Iris-setosa        49
# Name: class, dtype: int64

# %%
data.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    149.000000   149.000000    149.000000   149.000000
# mean       5.848322     3.051007      3.774497     1.205369
# std        0.828594     0.433499      1.759651     0.761292
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
data.plot()

# %%
plt.show()

# %%
data.dtypes
# Out:
# sepal length    float64
# sepal width     float64
# petal length    float64
# petal width     float64
# class            object
# dtype: object

# %%
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001AFF90FE128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AFF91BBE80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001AFF91D49B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AFF928BAC8>]], dtype=object)

# %%
plt.show()

# %%
sns.pairplot(data,hue="class")

# %%
plt.show()

# %%
sns.boxplot(data=data,x="class",y="sepal length")
plt.show()

# %%
sns.boxplot(data=data,x="class",y="sepal width")
plt.show()

# %%
sns.boxplot(data=data,x="class",y="petal length")
plt.show()

# %%
sns.boxplot(data=data,x="class",y="petal width")
plt.show()

# %%
data.plot(kind="box")

# %%
plt.show()
